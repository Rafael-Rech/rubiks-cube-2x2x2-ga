# %% [markdown]
# # Imports

# %%
from abc import ABC, abstractmethod
from random import randint
from math import inf
import datetime
from os import path, listdir

# %% [markdown]
# # Rubik's cube

# %%
class Movement:
  def __init__(self, positions1, positions2, prime, offset):
    self.positions1 = positions1
    self.positions2 = positions2
    self.offset = offset
    self.prime = prime
    if prime:
      self.positions1.reverse()
      self.positions2.reverse()
      self.offset.reverse()

  def apply(self, state):
    for i in range(2):
      aux = state[self.positions1[0] + self.offset[0] * i]
      state[self.positions1[0] + self.offset[0] * i] = state[self.positions1[1] + self.offset[1] * i]
      state[self.positions1[1] + self.offset[1] * i] = state[self.positions1[2] + self.offset[2] * i]
      state[self.positions1[2] + self.offset[2] * i] = state[self.positions1[3] + self.offset[3] * i]
      state[self.positions1[3] + self.offset[3] * i] = aux

    aux = state[self.positions2[0]]
    state[self.positions2[0]] = state[self.positions2[1]]
    state[self.positions2[1]] = state[self.positions2[2]]
    state[self.positions2[2]] = state[self.positions2[3]]
    state[self.positions2[3]] = aux

    return state

class MovementR(Movement):
  def __init__(self, prime):
    super().__init__([1, 13, 21, 5], [9, 8, 10, 11], prime, [2 for i in range(4)]) #ok

  def __str__(self):
    return "R'" if self.prime else "R"

class MovementL(Movement):
  def __init__(self, prime):
    super().__init__([0, 4, 20, 12],[18, 19, 17, 16], prime, [2 for i in range(4)]) #ok

  def __str__(self):
    return "L'" if self.prime else "L"

class MovementU(Movement):
  def __init__(self, prime):
    super().__init__([0, 8, 23, 16],[4, 6, 7, 5], prime, [1, 1, -1, 1]) #ok

  def __str__(self):
    return "U'" if self.prime else "U"

class MovementD(Movement):
  def __init__(self, prime):
    super().__init__([2, 18, 21, 10],[12, 14, 15, 13], prime, [1, 1, -1, 1])#ok

  def __str__(self):
    return "D'" if self.prime else "D"

class MovementF(Movement):
  def __init__(self, prime):
    super().__init__([6, 19, 13, 8],[0, 2, 3, 1], prime, [1, -2, -1, 2])#ok

  def __str__(self):
    return "F'" if self.prime else "F"

class MovementB(Movement):
  def __init__(self, prime):
    super().__init__([4, 9, 15, 18],[23, 21, 20, 22], prime, [1, 2, -1, -2])

  def __str__(self):
    return "B'" if self.prime else "B"

# %%
moves = [MovementB(True),  #0
         MovementB(False), #1
         MovementL(True),  #2
         MovementL(False), #3
         MovementD(True),  #4
         MovementD(False), #5
         MovementU(True),  #6
         MovementU(False), #7
         MovementR(True),  #8
         MovementR(False), #9
         MovementF(True),  #10
         MovementF(False), #11
         ]

movementNamesByIndex = {0 : "B'",
                        1 : "B",
                        2: "L'",
                        3: "L",
                        4: "D'",
                        5: "D",
                        6: "U'",
                        7: "U",
                        8: "R'",
                        9: "R",
                        10: "F'",
                        11: "F"}
movementIndexByName = { "B'" : 0,
                        "B" : 1,
                        "L'" : 2,
                        "L" : 3,
                        "D'" : 4,
                        "D" : 5,
                        "U'" : 6,
                        "U" : 7,
                        "R'" : 8,
                        "R" : 9,
                        "F'" : 10,
                        "F" : 11}

# %%
class Sequence:
  def __init__(self, movements : list, isRandom=False, size=0):
    global movementIndexByName
    if isRandom:
      self.movements = [randint(0, 11) for i in range(size)]
    else:
      self.movements = movements
      for i in range(len(self.movements)):
        if self.movements[i] in movementIndexByName.keys():
          self.movements[i] = movementIndexByName[self.movements[i]]

  def __str__(self):
    global movementNamesByIndex
    result = ''
    for move in self.movements:
      result = result + movementNamesByIndex[move] + ' '
    return result

# %%
class Cube:

  def __init__(self, state = [], solved=False):
    if solved:
      # self.state = ['W' for i in range(4)]       # 0 to 3
      # self.state.extend(['G' for i in range(4)]) # 4 to 7
      # self.state.extend(['O' for i in range(4)]) # 8 to 11
      # self.state.extend(['B' for i in range(4)]) # 12 to 15
      # self.state.extend(['R' for i in range(4)]) # 16 to 19
      # self.state.extend(['Y' for i in range(4)]) # 20 to 23
      self.state = []
      self.state.extend(["W1", "W2", "W3", "W4"])
      self.state.extend(["G1", "G2", "G3", "G4"])
      self.state.extend(["O1", "O2", "O3", "O4"])
      self.state.extend(["B1", "B2", "B3", "B4"])
      self.state.extend(["R1", "R2", "R3", "R4"])
      self.state.extend(["Y1", "Y2", "Y3", "Y4"])
    else:
      self.state = state
    # self.space = "           "
    self.space = "             "

  def movement(self, move : Movement):
    self.state = move.apply(self.state)

  def applySequence(self, movements: Sequence):
    global moves, solvedCube
    fitness = 24
    movesApplied = 0
    lastFitness = 0
    lastImprovementPoint = 0
    for move in movements.movements:
      self.movement(moves[move])
      movesApplied += 1
      newFitness = 24
      for i in range(len(self.state)):
        if self.state[i] == solvedCube.state[i]:
          newFitness -= 1
      if newFitness < fitness:
        lastImprovementPoint = movesApplied
        fitness = newFitness
      if newFitness == 0:
        return (1.0-(1.0/(lastImprovementPoint+1)), movesApplied-1, lastImprovementPoint)
      lastFitness = newFitness
    return (fitness + (1-(1.0/(lastImprovementPoint+1))), movesApplied-1, lastImprovementPoint)

  def shuffle(self, size=50):
    sequence = Sequence([], isRandom=True, size=size)
    print(sequence)
    self.applySequence(sequence)

  def printAloneFace(self, start):
    print(self.space, end = "")
    print(self.state[start:start+2])
    print(self.space, end = "")
    print(self.state[start+2:start+4])

  def printState(self):
    print()
    self.printAloneFace(4)

    print(self.state[16:18], self.state[0:2], self.state[8:10])
    print(self.state[18:20], self.state[2:4], self.state[10:12])


    self.printAloneFace(12)

    self.printAloneFace(20)

    print()

# %% [markdown]
# # Genetic Algorithm

# %%
class Chromosome:
  def __init__(self, size : int, sequence = None, isRandom = False):
    if isRandom:
      self.sequence = Sequence([], isRandom = True, size = size)
    else:
      self.sequence = sequence

    self.size = size
    self.correct()
    self.fitness, self.movesUntilSolved, self.lastImprovementPoint = self.calculateFitness()

  def correct(self):
    pos = 1
    while pos < len(self.sequence.movements):
      if (self.sequence.movements[pos] % 2 == 0 and self.sequence.movements[pos-1] == self.sequence.movements[pos] + 1) or (self.sequence.movements[pos] % 2 == 1 and self.sequence.movements[pos-1] == self.sequence.movements[pos] - 1) :
        self.sequence.movements.pop(pos)
        pos -= 1
      pos += 1
    while len(self.sequence.movements) < self.size:
      self.sequence.movements.append(randint(0, 11))

  def calculateFitness(self):
    global cube, solvedCube
    newCube = Cube(state=cube.state.copy())
    return newCube.applySequence(self.sequence)

  def __str__(self):
    return str(self.sequence) + " - Fitness = " + str(self.fitness) + f", movesUntilSolved = {self.movesUntilSolved}" + f", lastImprovementPoint = {self.lastImprovementPoint}"

# %%
class Crossover(ABC):
  @abstractmethod
  def crossover(parents : list):
    pass

class OnePointCrossover(Crossover):
  @staticmethod
  def crossover(parents : list, point=-1):
    chromosomeSize = parents[0].size
    if point == -1:
      point = randint(1, chromosomeSize - 1)
    moves = []
    moves.extend(parents[0].sequence.movements[i] for i in range(point))
    # moves = parents[0].sequence.movements[:point]
    moves.extend(parents[1].sequence.movements[i] for i in range(point, chromosomeSize))
    # moves.extend(parents[1].sequence.movements[point:])
    sequence = Sequence(moves)
    return Chromosome(chromosomeSize, sequence)

class ImprovementPointCrossover(Crossover):
  @staticmethod
  def crossover(parents : list):
    parents.sort(key = lambda x:x.fitness)
    return OnePointCrossover.crossover(parents, parents[0].lastImprovementPoint if parents[0].lastImprovementPoint < parents[0].size / 2 else -1)

# %%
class Mutation(ABC):
  @abstractmethod
  def mutate(chromosome : Chromosome):
    pass

class ExchangeMutation(Mutation):
  @staticmethod
  def mutate(chromosome : Chromosome):
    point1 = randint(0, chromosome.size - 1)
    point2 = randint(0, chromosome.size - 1)
    while point1 == point2:
      point2 = randint(0, chromosome.size - 1)
    newSequence = chromosome.sequence.movements.copy()
    newSequence[point1], newSequence[point2] = newSequence[point2], newSequence[point1]
    return Chromosome(chromosome.size, sequence = Sequence(newSequence))

class ValueMutation(Mutation):
  @staticmethod
  def mutate(chromosome : Chromosome):
    point = randint(0, chromosome.size - 1)
    newSequence = chromosome.sequence.movements.copy()
    newSequence[point] = randint(0, 11)
    return Chromosome(chromosome.size, sequence = Sequence(newSequence))

# %%
class GeneticAlgorithm:
  def __init__(self,
               numberOfGenerations : int,
               populationSize : int,
               chromosomeSize : int,
               numberOfCrossovers : int,
               mutationRate : int,
               elitismRate : float,
               maxSimilarityRate : float
               ):
    self.chromosomeSize = chromosomeSize
    self.numberOfGenerations = numberOfGenerations
    self.numberOfCrossovers = numberOfCrossovers
    self.mutationRate = mutationRate
    self.elitismRate = elitismRate
    self.maxSimilarityRate = maxSimilarityRate
    self.populationSize = populationSize
    self.solutionGeneration = -1
    self.bestFitnessPerGenerations = []

  def stopCriteria(self, t, bestSolution):
    # return bestSolution.fitness == 0

    # if self.solutionGeneration == -1:
    #   if bestSolution.fitness < 1:
    #     self.solutionGeneration = t
    #   return False
    # return t >= self.numberOfGenerations + self.solutionGeneration and bestSolution.fitness < 1

    return bestSolution.fitness < 1

  def run(self):
    global cube, solvedCube
    initialTime = datetime.datetime.now()
    self.population = []
    for i in range(self.populationSize):
      self.population.append(Chromosome(size = self.chromosomeSize, isRandom = True))
    t = 0
    self.population.sort(key = lambda x : x.fitness, reverse=False)

    while not self.stopCriteria(t, self.population[0]):
      similarity = 0
      for chromosome in self.population:
        similarity += chromosome.fitness
      similarity /= len(self.population)
      if similarity >= self.maxSimilarityRate * self.population[0].fitness:
        self.population = self.population[:len(self.population)//4]
        while len(self.population) < self.populationSize:
          chromosome = Chromosome(size = self.chromosomeSize, isRandom = True)
          self.population.append(chromosome)

      newPopulation = []
      for crossover in range(self.numberOfCrossovers):
        parent1 = randint(0, self.populationSize - 1)
        parent2 = randint(0, self.populationSize - 1)
        while parent1 == parent2:
          parent2 = randint(0, self.populationSize - 1)
        newPopulation.append(ImprovementPointCrossover.crossover([self.population[parent1], self.population[parent2]]))
        # newPopulation.append(OnePointCrossover.crossover([self.population[parent1], self.population[parent2]]))
        # parents = [self.population[parent1], self.population[parent2]]
        # newPopulation.append(OnePointCrossover.crossover(parents) if randint(0,1) else ImprovementPointCrossover.crossover(parents))
        roulette = randint(0, 99)
        if roulette < self.mutationRate:
          newPopulation[crossover] = ExchangeMutation.mutate(newPopulation[crossover])
          # newPopulation[crossover] = ValueMutation.mutate(newPopulation[crossover])

      for i in range(int(self.elitismRate * self.populationSize)):
        newPopulation.append(self.population[i])
      newPopulation.sort(key = lambda x : x.fitness, reverse=False)
      self.population = newPopulation[:self.populationSize]

      self.bestFitnessPerGenerations.append(self.population[0].fitness)
      t += 1
      if t%1000==0:
        print(f"Generation {t}")
        print(t, self.population[0])
        cubeAfterSequence = Cube(cube.state.copy(), False)
        cubeAfterSequence.applySequence(Sequence(self.population[0].sequence.movements[:self.population[0].movesUntilSolved + 1].copy()))
        cubeAfterSequence.printState()
        print()

    finalTime = datetime.datetime.now()
    time = finalTime - initialTime
    return self.population[0], t, time.total_seconds(), self.bestFitnessPerGenerations

# %%
def main():
  global cube, solvedCube

  cube = Cube(solved=True)
  solvedCube = Cube(solved=True)
  cube.shuffle()

  geneticAlgorithm = GeneticAlgorithm(
                          numberOfGenerations = 250,
                          populationSize = 100,
                          chromosomeSize = 25,
                          numberOfCrossovers = 100,
                          mutationRate = 10,
                          elitismRate = 0.05,
                          maxSimilarityRate = 0.90)

  print(f"Starting algorithm")
  print("Cube state:")
  cube.printState()
  solution, generations, time, bestFitnessPerGeneration = geneticAlgorithm.run()
  print(f"Genetic Algorithm completed")
  print()
  print("Applying solution")
  print(solution)
  print(f"Sequence to apply: {[movementNamesByIndex[i] for i in solution.sequence.movements[:solution.movesUntilSolved + 1].copy()]}")

  # cubeAfterSequence = Cube(cube.state.copy(), False)
  cubeAfterSequence = Cube([a for a in cube.state], False)
  print("Before applying:")
  cubeAfterSequence.printState()
  cubeAfterSequence.applySequence(Sequence(solution.sequence.movements[:solution.movesUntilSolved + 1].copy()))
  print("After applying")
  cubeAfterSequence.printState()

if __name__ == "__main__":
  """run"""
  main()
# Out:
# D' F F L D' L' U' F' D' L U' B' R' D D' U' L' F' R L
# Starting algorithm
# Cube state:
#
#              ['B3', 'O2']
#              ['O4', 'R4']
# ['Y1', 'B4'] ['Y2', 'B1'] ['W3', 'Y4']
# ['G3', 'G1'] ['R1', 'G4'] ['O1', 'W4']
#              ['Y3', 'W2']
#              ['W1', 'B2']
#              ['R2', 'O3']
#              ['R3', 'G2']
#
# Geração 1000
# 1000 U B' L D R D R' F D' L' L' F' U B L' B' D R R L B' B' U B B'  - Fitness = 6.928571428571429, movesUntilSolved = 24, lastImprovementPoint = 13
#
#              ['O2', 'G4']
#              ['B2', 'R3']
# ['G2', 'O3'] ['W4', 'Y1'] ['B3', 'W2']
# ['G3', 'R4'] ['W3', 'R1'] ['Y3', 'Y2']
#              ['B1', 'G1']
#              ['W1', 'O4']
#              ['R2', 'B4']
#              ['Y4', 'O1']
#
#
# Geração 2000
# 2000 U B' L D R D R' F D' L' L' F' U B F' L' B B D' F U' F' L' F' U'  - Fitness = 6.928571428571429, movesUntilSolved = 24, lastImprovementPoint = 13
#
#              ['R1', 'O1']
#              ['R4', 'B2']
# ['Y3', 'B1'] ['W3', 'O3'] ['W4', 'G4']
# ['O2', 'B3'] ['Y1', 'W1'] ['R2', 'Y2']
#              ['R3', 'G3']
#              ['G2', 'O4']
#              ['Y4', 'B4']
#              ['G1', 'W2']
#
#
# Geração 3000
# 3000 U D R U' F' U' D' B F B' D' U' D' B' U' B' F L U' D L' R D' B' L'  - Fitness = 6.916666666666667, movesUntilSolved = 24, lastImprovementPoint = 11
#
#              ['O4', 'G2']
#              ['Y3', 'B2']
# ['Y2', 'R1'] ['G1', 'O3'] ['W4', 'O2']
# ['G3', 'O1'] ['W2', 'B1'] ['R4', 'Y1']
#              ['G4', 'W3']
#              ['W1', 'B3']
#              ['R2', 'R3']
#              ['B4', 'Y4']
#
#
# Geração 4000
# 4000 U D R U' F' D' U' B F B' D' D' R' D R' F D' L' U R' D L' B F B  - Fitness = 6.916666666666667, movesUntilSolved = 24, lastImprovementPoint = 11
#
#              ['G2', 'R3']
#              ['W4', 'G1']
# ['Y4', 'B2'] ['O3', 'Y3'] ['R1', 'Y1']
# ['Y2', 'G4'] ['O1', 'W3'] ['B1', 'W1']
#              ['W2', 'R4']
#              ['B4', 'G3']
#              ['O4', 'R2']
#              ['O2', 'B3']
#
#
# Geração 5000
# 5000 U D R' U' F' U' D' B F B' D' L' F L F' F' D L' R F R' B' B' F R  - Fitness = 6.916666666666667, movesUntilSolved = 24, lastImprovementPoint = 11
#
#              ['R4', 'B4']
#              ['R2', 'R1']
# ['W3', 'W1'] ['G3', 'G1'] ['Y3', 'Y2']
# ['O2', 'W4'] ['O3', 'W2'] ['G4', 'R3']
#              ['B2', 'O1']
#              ['G2', 'Y1']
#              ['Y4', 'B3']
#              ['B1', 'O4']
#
#
# Geração 6000
# 6000 D U R U' F' U' D' B' F B D' U F' B' R B D' F B U' F' U L' F' R'  - Fitness = 6.916666666666667, movesUntilSolved = 24, lastImprovementPoint = 11
#
#              ['B1', 'G2']
#              ['O1', 'R3']
# ['R4', 'G4'] ['W2', 'Y1'] ['B3', 'O2']
# ['R1', 'G3'] ['W1', 'Y2'] ['B4', 'O3']
#              ['R2', 'O4']
#              ['Y3', 'W4']
#              ['G1', 'B2']
#              ['W3', 'Y4']
#
#
# Geração 7000
# 7000 D U R' U' F' U' D' B' F B D' B' L R' B F' R L' B' R L F' D F' R'  - Fitness = 6.916666666666667, movesUntilSolved = 24, lastImprovementPoint = 11
#
#              ['O3', 'Y3']
#              ['O1', 'G3']
# ['B2', 'G4'] ['W2', 'R2'] ['W1', 'R1']
# ['B3', 'W3'] ['B1', 'Y4'] ['O2', 'B4']
#              ['R4', 'G2']
#              ['Y1', 'Y2']
#              ['R3', 'O4']
#              ['W4', 'G1']
#
#
# Geração 8000
# 8000 D U R U' F' U' D' B' F B D' D' B F D F' D R' D B' U' D' F F B  - Fitness = 6.916666666666667, movesUntilSolved = 24, lastImprovementPoint = 11
#
#              ['Y1', 'Y2']
#              ['G1', 'W3']
# ['R3', 'Y3'] ['R1', 'R4'] ['B1', 'O4']
# ['G4', 'W1'] ['R2', 'W4'] ['O3', 'Y4']
#              ['G3', 'B2']
#              ['O1', 'G2']
#              ['W2', 'O2']
#              ['B3', 'B4']
#
#
# Geração 9000
# 9000 U D R U' F' D' U' B' F B D' L' R' D U' L B U F' R F' D' B' L' F'  - Fitness = 6.916666666666667, movesUntilSolved = 24, lastImprovementPoint = 11
#
#              ['G3', 'Y2']
#              ['Y3', 'G4']
# ['W1', 'R1'] ['G1', 'W2'] ['O1', 'O4']
# ['G2', 'R4'] ['W3', 'W4'] ['O3', 'R3']
#              ['B1', 'B2']
#              ['Y4', 'Y1']
#              ['O2', 'B3']
#              ['R2', 'B4']
#
#
# Geração 10000
# 10000 D R B' L F' B' D R' F' L' B U' D F D' R F' L' U' B D' F R U' D'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['W3', 'O2']
#              ['G3', 'Y3']
# ['B1', 'R2'] ['W1', 'R1'] ['G1', 'Y4']
# ['W4', 'B4'] ['O4', 'W2'] ['G4', 'R3']
#              ['Y2', 'O1']
#              ['O3', 'Y1']
#              ['B2', 'B3']
#              ['R4', 'G2']
#
#
# Geração 11000
# 11000 D R B' L B' F' D D F' B F' U D R L D' L' B D R L' F B' L' F'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['O4', 'R1']
#              ['B1', 'B3']
# ['Y2', 'W3'] ['R4', 'R3'] ['Y1', 'G1']
# ['W4', 'G2'] ['Y4', 'R2'] ['G3', 'G4']
#              ['O2', 'W1']
#              ['O3', 'W2']
#              ['B2', 'O1']
#              ['B4', 'Y3']
#
#
# Geração 12000
# 12000 D R B' L B' F' D D L' R' R' U' R' R' R' D' U' B U D L' R U' B D  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['W2', 'O2']
#              ['G1', 'Y1']
# ['G4', 'Y3'] ['R1', 'B3'] ['R3', 'Y4']
# ['B1', 'G3'] ['W1', 'Y2'] ['B4', 'W4']
#              ['R2', 'O4']
#              ['R4', 'B2']
#              ['W3', 'O3']
#              ['O1', 'G2']
#
#
# Geração 13000
# 13000 D R B' L B' F' D R' B R D R B' D F' L L L L D D F D' D' L  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['W1', 'Y2']
#              ['W4', 'R4']
# ['R2', 'B2'] ['O3', 'B1'] ['W3', 'O4']
# ['R1', 'B3'] ['Y1', 'Y4'] ['O2', 'O1']
#              ['R3', 'G2']
#              ['Y3', 'G4']
#              ['G1', 'W2']
#              ['G3', 'B4']
#
#
# Geração 14000
# 14000 D R B' L B' F' D L U' U' D' F' F' R' D U R D D D F' U' R' R' R'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['B1', 'R3']
#              ['B4', 'B2']
# ['R4', 'Y2'] ['O4', 'O3'] ['W4', 'Y1']
# ['R1', 'R2'] ['G3', 'Y4'] ['O2', 'W2']
#              ['W1', 'G2']
#              ['Y3', 'O1']
#              ['G1', 'G4']
#              ['W3', 'B3']
#
#
# Geração 15000
# 15000 D R B' L B' F' D R R R B L F R R F D' B L' F B L' B R B'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['R2', 'W4']
#              ['B4', 'R1']
# ['G3', 'Y2'] ['O4', 'G1'] ['Y3', 'B2']
# ['Y4', 'G4'] ['O1', 'B1'] ['R4', 'B3']
#              ['W2', 'W3']
#              ['O2', 'R3']
#              ['G2', 'Y1']
#              ['W1', 'O3']
#
#
# Geração 16000
# 16000 D R B' L B' F' D F R' F' R' D' U' R B L' F' U R B R L R F' L'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['G2', 'R4']
#              ['B4', 'W1']
# ['Y4', 'Y2'] ['O4', 'G3'] ['R2', 'B1']
# ['B2', 'Y3'] ['G1', 'Y1'] ['R3', 'G4']
#              ['R1', 'B3']
#              ['W4', 'W2']
#              ['O3', 'O1']
#              ['O2', 'W3']
#
#
# Geração 17000
# 17000 D R B' L F' B' D R U' L' D' R' B' F' R R F F F D' D' R U' U' U'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['G4', 'B3']
#              ['Y4', 'R2']
# ['O1', 'G2'] ['O2', 'W1'] ['G3', 'R3']
# ['R4', 'G1'] ['R1', 'O3'] ['B2', 'Y2']
#              ['Y3', 'W4']
#              ['W3', 'O4']
#              ['B1', 'B4']
#              ['W2', 'Y1']
#
#
# Geração 18000
# 18000 D R B' L F' B' D B R' F' L' U D' L B' D R' R' L' D' L' D U' F B'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['B1', 'G4']
#              ['Y3', 'Y4']
# ['R4', 'R1'] ['G1', 'G2'] ['O2', 'W2']
# ['Y1', 'Y2'] ['B4', 'W1'] ['R2', 'W4']
#              ['O4', 'G3']
#              ['R3', 'B2']
#              ['B3', 'O3']
#              ['W3', 'O1']
#
#
# Geração 19000
# 19000 D R B' L F' B' D D D F' R U' B' R' U R' F D' R' U' L D' L' D' B  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['W3', 'Y2']
#              ['B3', 'R1']
# ['B1', 'R3'] ['Y1', 'G1'] ['Y3', 'O4']
# ['Y4', 'G4'] ['O1', 'W4'] ['O3', 'W1']
#              ['W2', 'B2']
#              ['O2', 'G3']
#              ['G2', 'R2']
#              ['R4', 'B4']
#
#
# Geração 20000
# 20000 D R B' L F' B' D D R U' D U B' R' D' U R' U' F' U L U U U R'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['O3', 'Y1']
#              ['O4', 'O2']
# ['B2', 'B4'] ['Y2', 'Y4'] ['G2', 'B3']
# ['R1', 'G4'] ['O1', 'W1'] ['R2', 'B1']
#              ['W2', 'G3']
#              ['Y3', 'W3']
#              ['G1', 'R4']
#              ['W4', 'R3']
#
#
# Geração 21000
# 21000 D R B' L F' B' D U D' U R' U' R' L U L R U' D' L' D B L D' B'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['G3', 'W4']
#              ['Y4', 'B3']
# ['W1', 'G2'] ['O2', 'R3'] ['Y1', 'B2']
# ['B4', 'G1'] ['R1', 'G4'] ['O1', 'B1']
#              ['Y3', 'W2']
#              ['O4', 'W3']
#              ['Y2', 'R4']
#              ['R2', 'O3']
#
#
# Geração 22000
# 22000 D R B' L F' B' D L B R U' L' D F' L U' L' B' R' L F R' F U B  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['R4', 'B4']
#              ['G3', 'W2']
# ['W3', 'R2'] ['W1', 'O1'] ['G4', 'Y2']
# ['Y4', 'O3'] ['B2', 'B3'] ['Y1', 'Y3']
#              ['W4', 'R3']
#              ['O2', 'R1']
#              ['G2', 'G1']
#              ['B1', 'O4']
#
#
# Geração 23000
# 23000 D R B' L B' F' D U' F U F R' L' B' L B' L B' D' F L B' U U L'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['W3', 'R1']
#              ['G3', 'O1']
# ['B1', 'R2'] ['W1', 'G4'] ['W2', 'G1']
# ['Y1', 'O3'] ['B2', 'G2'] ['Y4', 'O4']
#              ['W4', 'O2']
#              ['R3', 'B4']
#              ['B3', 'Y2']
#              ['R4', 'Y3']
#
#
# Geração 24000
# 24000 D R B' L B' F' D U R D' B' R' D U' B F' B B F' F' L D' B R U'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['B1', 'G1']
#              ['G2', 'R2']
# ['R4', 'O2'] ['Y4', 'W1'] ['G3', 'Y3']
# ['O3', 'W2'] ['G4', 'R3'] ['B3', 'B4']
#              ['O1', 'Y1']
#              ['B2', 'Y2']
#              ['W4', 'O4']
#              ['W3', 'R1']
#
#
# Geração 25000
# 25000 D R B' L B' F' D U' B' B' U R' L F D' U' L' B L' D F' R L' F R'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y3', 'B1']
#              ['O2', 'G4']
# ['G1', 'Y4'] ['G2', 'W2'] ['O1', 'W3']
# ['B4', 'B2'] ['W4', 'Y1'] ['R3', 'G3']
#              ['O3', 'B3']
#              ['O4', 'R2']
#              ['Y2', 'W1']
#              ['R1', 'R4']
#
#
# Geração 26000
# 26000 D R B' L F' B' D U L' U' L' R D' F' D F F B F L' R' L' B U' D'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['R1', 'Y2']
#              ['W1', 'G4']
# ['Y3', 'G3'] ['R2', 'W2'] ['O1', 'O4']
# ['W3', 'Y1'] ['R3', 'Y4'] ['O2', 'B2']
#              ['B3', 'G2']
#              ['B1', 'O3']
#              ['R4', 'W4']
#              ['G1', 'B4']
#
#
# Geração 27000
# 27000 D R B' L F' B' D F' L' R' D B' D R L B F L B' U' R' D D R' D'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y2', 'R1']
#              ['B3', 'O1']
# ['B4', 'R3'] ['Y1', 'G4'] ['W2', 'G1']
# ['G3', 'B1'] ['R4', 'B2'] ['W4', 'Y4']
#              ['W3', 'O3']
#              ['W1', 'G2']
#              ['R2', 'O2']
#              ['O4', 'Y3']
#
#
# Geração 28000
# 28000 D R B' L F' B' D U' D' B' D L' B' F D L' U' D F' U B' R' U' F' U  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y4', 'R2']
#              ['B3', 'B4']
# ['O2', 'R3'] ['Y1', 'Y2'] ['O4', 'W1']
# ['O3', 'R1'] ['Y3', 'G4'] ['O1', 'W3']
#              ['G1', 'W2']
#              ['B2', 'R4']
#              ['W4', 'B1']
#              ['G2', 'G3']
#
#
# Geração 29000
# 29000 D R B' L B' F' D R' L D D R' D R B U' U' D' L' U L' R F R' L  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y4', 'R1']
#              ['O4', 'W1']
# ['O2', 'B4'] ['Y2', 'G3'] ['R2', 'G1']
# ['Y1', 'O3'] ['B2', 'O1'] ['W2', 'B1']
#              ['W4', 'G4']
#              ['R3', 'W3']
#              ['B3', 'R4']
#              ['G2', 'Y3']
#
#
# Geração 30000
# 30000 D R B' L B' F' D U' D F' L' F' D F D' U' F B' F' U' F' R' B' L' R  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y3', 'G2']
#              ['W1', 'O4']
# ['G1', 'G3'] ['R2', 'B4'] ['Y2', 'O2']
# ['W4', 'B3'] ['Y1', 'W3'] ['B1', 'O1']
#              ['R3', 'R4']
#              ['O3', 'G4']
#              ['B2', 'W2']
#              ['R1', 'Y4']
#
#
# Geração 31000
# 31000 D R B' L B' F' D U F' F' B F' L' B' R' R' L' U' U' B' D F U R' L'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y4', 'W3']
#              ['R3', 'W1']
# ['O2', 'Y1'] ['B3', 'G3'] ['R2', 'R4']
# ['W2', 'G1'] ['R1', 'O4'] ['Y2', 'O3']
#              ['Y3', 'B4']
#              ['G4', 'W4']
#              ['O1', 'B2']
#              ['G2', 'B1']
#
#
# Geração 32000
# 32000 D R B' L B' F' D F U' R' B F R D' B D B R' F L B' F' U' B B  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['R4', 'B3']
#              ['Y3', 'B2']
# ['W3', 'R1'] ['G1', 'O3'] ['W4', 'R3']
# ['W2', 'G2'] ['Y4', 'B4'] ['O4', 'G3']
#              ['O2', 'Y2']
#              ['G4', 'R2']
#              ['O1', 'W1']
#              ['B1', 'Y1']
#
#
# Geração 33000
# 33000 D R B' L B' F' D L' F' F' U D L D' L R F B F D' L L B' B' D  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y1', 'R2']
#              ['B1', 'B2']
# ['R3', 'W3'] ['R4', 'O3'] ['W4', 'W1']
# ['Y2', 'Y3'] ['G1', 'O2'] ['G2', 'W2']
#              ['R1', 'Y4']
#              ['B4', 'O1']
#              ['O4', 'G4']
#              ['B3', 'G3']
#
#
# Geração 34000
# 34000 D R B' L F' B' D F D' F U D L' L' R' L B U D R' U R' L' F U'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y1', 'B1']
#              ['R1', 'W2']
# ['R3', 'G1'] ['Y3', 'O1'] ['G4', 'W3']
# ['W1', 'G2'] ['Y4', 'W4'] ['O3', 'Y2']
#              ['O2', 'B2']
#              ['R2', 'O4']
#              ['G3', 'B4']
#              ['B3', 'R4']
#
#
# Geração 35000
# 35000 D R B' L B' F' D F L D B' U F' D' U' D B' D U F D' B' R R R  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['G1', 'W2']
#              ['Y4', 'G3']
# ['R1', 'G2'] ['O2', 'R2'] ['W1', 'O1']
# ['B1', 'Y2'] ['B4', 'R3'] ['B3', 'W4']
#              ['O4', 'Y1']
#              ['R4', 'B2']
#              ['W3', 'O3']
#              ['Y3', 'G4']
#
#
# Geração 36000
# 36000 D R B' L B' F' D U' D' U B' R' B U B R' U R L' F' L U U L R  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['W4', 'G3']
#              ['G4', 'Y3']
# ['O3', 'W2'] ['O1', 'R1'] ['G1', 'R2']
# ['Y2', 'W3'] ['B1', 'G2'] ['Y4', 'Y1']
#              ['R4', 'O2']
#              ['B4', 'B3']
#              ['O4', 'R3']
#              ['B2', 'W1']
#
#
# Geração 37000
# 37000 D R B' L B' F' D R R F U' B D U' U' B R R R L F R' F R U  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['R1', 'B1']
#              ['B3', 'O1']
# ['Y3', 'R3'] ['Y1', 'G4'] ['W2', 'W3']
# ['O3', 'W1'] ['R2', 'Y2'] ['B4', 'Y4']
#              ['G3', 'O4']
#              ['B2', 'G2']
#              ['W4', 'O2']
#              ['G1', 'R4']
#
#
# Geração 38000
# 38000 D R B' L F' B' D F' D L R U' R' U' R B' R' F D' U' B' F R F' L'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['O1', 'R3']
#              ['O2', 'B2']
# ['W2', 'Y4'] ['G2', 'O3'] ['W4', 'Y1']
# ['R2', 'R1'] ['Y3', 'W3'] ['B1', 'O4']
#              ['G1', 'R4']
#              ['G3', 'B4']
#              ['W1', 'Y2']
#              ['G4', 'B3']
#
#
# Geração 39000
# 39000 D R B' L B' F' D R' F' B' F U B' F' L B U' F B' L B F' F' U R  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['W4', 'G4']
#              ['W1', 'B4']
# ['O3', 'G3'] ['R2', 'Y2'] ['O4', 'W2']
# ['G2', 'R1'] ['Y3', 'R4'] ['W3', 'Y1']
#              ['G1', 'B1']
#              ['Y4', 'B3']
#              ['O2', 'R3']
#              ['B2', 'O1']
#
#
# Geração 40000
# 40000 D R B' L B' F' D D L B D' R' F U' F' F' B' F' F' B' F' D D L' D  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['B1', 'Y3']
#              ['B4', 'O3']
# ['R4', 'Y2'] ['O4', 'W4'] ['B2', 'R1']
# ['G2', 'R3'] ['B3', 'O1'] ['W2', 'W1']
#              ['Y1', 'G4']
#              ['Y4', 'G3']
#              ['O2', 'R2']
#              ['W3', 'G1']
#
#
# Geração 41000
# 41000 D R B' L B' F' D L' L' U' F' L R B B F' B' D U' D L' F' U' B' D'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['G4', 'Y2']
#              ['W4', 'G3']
# ['O1', 'B2'] ['O3', 'R2'] ['W1', 'O4']
# ['B1', 'B3'] ['Y1', 'Y3'] ['G1', 'G2']
#              ['R3', 'R1']
#              ['R4', 'O2']
#              ['W3', 'Y4']
#              ['W2', 'B4']
#
#
# Geração 42000
# 42000 D R B' L B' F' D B L B B D L D' U' B U D' F' D' U F' L F F  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y1', 'R2']
#              ['O3', 'O1']
# ['R3', 'W4'] ['B2', 'G4'] ['W2', 'W1']
# ['G2', 'B1'] ['R4', 'Y2'] ['B4', 'G1']
#              ['W3', 'O4']
#              ['Y4', 'Y3']
#              ['O2', 'R1']
#              ['B3', 'G3']
#
#
# Geração 43000
# 43000 D R B' L F' B' D U' D F' D' U' D R' L' F U F' R' F' B L F D' D  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['O4', 'G1']
#              ['O2', 'Y1']
# ['Y2', 'Y4'] ['G2', 'B3'] ['R3', 'Y3']
# ['B2', 'R2'] ['G3', 'B1'] ['R4', 'W2']
#              ['W1', 'W3']
#              ['W4', 'O1']
#              ['O3', 'G4']
#              ['B4', 'R1']
#
#
# Geração 44000
# 44000 D R B' L B' F' D U' R' L' L' L' R D' L B' D U' B B U' L F' L U  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['R1', 'B1']
#              ['O2', 'B3']
# ['Y3', 'Y4'] ['G2', 'R3'] ['Y1', 'W3']
# ['O1', 'W4'] ['O3', 'B4'] ['O4', 'G3']
#              ['B2', 'Y2']
#              ['W2', 'R2']
#              ['G4', 'W1']
#              ['G1', 'R4']
#
#
# Geração 45000
# 45000 D R B' L B' F' D R L R F F U' L D' R' R' D' L B B L F D' B'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y4', 'W2']
#              ['R4', 'B3']
# ['O2', 'B1'] ['W3', 'R3'] ['Y1', 'O1']
# ['O3', 'O4'] ['Y2', 'G3'] ['W1', 'R1']
#              ['B4', 'R2']
#              ['B2', 'G1']
#              ['W4', 'Y3']
#              ['G2', 'G4']
#
#
# Geração 46000
# 46000 D R B' L B' F' D F D R L B D' U U F' R' D U' R D' D' R D D  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['O4', 'Y4']
#              ['B2', 'G4']
# ['Y2', 'O3'] ['W4', 'W2'] ['O1', 'G2']
# ['B1', 'G1'] ['R1', 'R3'] ['B3', 'W1']
#              ['Y3', 'Y1']
#              ['R4', 'G3']
#              ['W3', 'R2']
#              ['B4', 'O2']
#
#
# Geração 47000
# 47000 D R B' L B' F' D B' R' F L L U D' U R' D U' L' U L L D U' L'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['W4', 'Y2']
#              ['G2', 'W3']
# ['O3', 'O2'] ['Y4', 'R4'] ['B1', 'O4']
# ['Y3', 'W2'] ['G4', 'R3'] ['B3', 'G3']
#              ['O1', 'Y1']
#              ['G1', 'R2']
#              ['R1', 'W1']
#              ['B2', 'B4']
#
#
# Geração 48000
# 48000 D R B' L B' F' D B U B' L' F B' F D B' R' F' B L' U L' F L' U'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['W1', 'G1']
#              ['O1', 'Y4']
# ['R2', 'G4'] ['W2', 'G2'] ['O2', 'Y3']
# ['Y1', 'O3'] ['B2', 'Y2'] ['B4', 'B1']
#              ['W4', 'O4']
#              ['R3', 'W3']
#              ['B3', 'R4']
#              ['G3', 'R1']
#
#
# Geração 49000
# 49000 D R B' L F' B' D F' R' F L' D' L B' U L' D' D' U' F' B D F' B' D'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['B1', 'B3']
#              ['G1', 'W2']
# ['R4', 'Y3'] ['R1', 'O1'] ['G4', 'R3']
# ['W4', 'G2'] ['Y4', 'W1'] ['R2', 'O4']
#              ['O2', 'G3']
#              ['O3', 'B4']
#              ['B2', 'Y2']
#              ['W3', 'Y1']
#
#
# Geração 50000
# 50000 D R B' L F' B' D R' U D' B B B U F' B' B' B' U R' B' U L B' F'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y2', 'O1']
#              ['Y3', 'G3']
# ['B4', 'R1'] ['G1', 'R2'] ['W1', 'G4']
# ['Y1', 'O3'] ['B2', 'W3'] ['B1', 'Y4']
#              ['W4', 'R4']
#              ['R3', 'G2']
#              ['B3', 'O2']
#              ['O4', 'W2']
#
#
# Geração 51000
# 51000 D R B' L F' B' D U' F F R' B' F' U' F R D F' L' F U' B R U' R  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['B1', 'W2']
#              ['O3', 'O2']
# ['R4', 'W4'] ['B2', 'Y4'] ['G2', 'O1']
# ['B3', 'R2'] ['G3', 'Y2'] ['B4', 'R1']
#              ['W1', 'O4']
#              ['Y1', 'G1']
#              ['R3', 'Y3']
#              ['W3', 'G4']
#
#
# Geração 52000
# 52000 D R B' L F' B' D U' D' U D' B' U' F B' D' F R B D B' B' F' L B'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['G1', 'R2']
#              ['Y4', 'G4']
# ['R1', 'G2'] ['O2', 'W2'] ['O1', 'W1']
# ['O4', 'B2'] ['W4', 'B1'] ['R4', 'Y1']
#              ['O3', 'W3']
#              ['Y2', 'B3']
#              ['B4', 'R3']
#              ['Y3', 'G3']
#
#
# Geração 53000
# 53000 D R B' L F' B' D R L' U L' B' R' B F L' F F U' D U F L D' R  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['O2', 'B2']
#              ['G3', 'G4']
# ['G2', 'R2'] ['W1', 'W2'] ['O1', 'O3']
# ['Y3', 'R4'] ['W3', 'B3'] ['Y1', 'B4']
#              ['B1', 'R3']
#              ['G1', 'Y2']
#              ['R1', 'O4']
#              ['Y4', 'W4']
#
#
# Geração 54000
# 54000 D R B' L F' B' D L' U' B' F R D' B' R' F' D U R R B' B' U' B' U'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y4', 'W3']
#              ['B3', 'R1']
# ['O2', 'R3'] ['Y1', 'G1'] ['Y3', 'R4']
# ['G3', 'B4'] ['O4', 'O3'] ['B2', 'W2']
#              ['Y2', 'W4']
#              ['W1', 'O1']
#              ['R2', 'G4']
#              ['G2', 'B1']
#
#
# Geração 55000
# 55000 D R B' L F' B' D R D L R' B' L U B R R F' L R' F L' R' D' U  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['B4', 'R1']
#              ['G2', 'G3']
# ['O4', 'O2'] ['Y4', 'R2'] ['W1', 'G1']
# ['O1', 'B1'] ['R4', 'W4'] ['O3', 'R3']
#              ['W3', 'B2']
#              ['W2', 'Y1']
#              ['G4', 'B3']
#              ['Y2', 'Y3']
#
#
# Geração 56000
# 56000 D R B' L F' B' D B F B' F B D' B R' F R U D F R U B U F'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['B2', 'R1']
#              ['B4', 'B3']
# ['W4', 'Y2'] ['O4', 'R3'] ['Y1', 'G1']
# ['Y4', 'R2'] ['G3', 'W3'] ['B1', 'W2']
#              ['W1', 'R4']
#              ['O2', 'O1']
#              ['G2', 'G4']
#              ['O3', 'Y3']
#
#
# Geração 57000
# 57000 D R B' L F' B' D L R L L R' L' L' D U' L F' L' R L F B' L B  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['O4', 'G1']
#              ['W3', 'W1']
# ['Y2', 'R4'] ['B1', 'G3'] ['R2', 'Y3']
# ['G4', 'Y4'] ['O2', 'B3'] ['Y1', 'B2']
#              ['G2', 'R3']
#              ['O1', 'O3']
#              ['W2', 'W4']
#              ['B4', 'R1']
#
#
# Geração 58000
# 58000 D R B' L F' B' D U' F U L F B' D' R' D D F F U L' B' D' R F  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y3', 'Y2']
#              ['W1', 'Y1']
# ['G1', 'G3'] ['R2', 'B3'] ['R3', 'O4']
# ['R4', 'O1'] ['W2', 'O3'] ['B2', 'Y4']
#              ['G4', 'W4']
#              ['W3', 'G2']
#              ['B1', 'O2']
#              ['R1', 'B4']
#
#
# Geração 59000
# 59000 D R B' L F' B' D D U' F' L' B F F U R D' L' L' D L' F' R L' F  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['G3', 'R3']
#              ['Y4', 'B4']
# ['W1', 'G2'] ['O2', 'Y2'] ['O4', 'Y1']
# ['R4', 'W2'] ['G4', 'G1'] ['R1', 'O3']
#              ['O1', 'Y3']
#              ['W3', 'W4']
#              ['B1', 'B2']
#              ['R2', 'B3']
#
#
# Geração 60000
# 60000 D R B' L F' B' D F R F U' L B' F' D' L B D F B' U' R' R' U U'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['R3', 'G4']
#              ['W1', 'O2']
# ['B3', 'G3'] ['R2', 'Y4'] ['G2', 'W2']
# ['W3', 'O3'] ['B2', 'O4'] ['Y2', 'R1']
#              ['W4', 'B4']
#              ['B1', 'G1']
#              ['R4', 'Y3']
#              ['Y1', 'O1']
#
#
# Geração 61000
# 61000 D R B' L B' F' D R' B' R D' B' D' B' U' F' L R L' D B' F' B' F U'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['O1', 'G3']
#              ['Y1', 'Y3']
# ['W2', 'B3'] ['R3', 'R1'] ['G1', 'R2']
# ['O2', 'O3'] ['B2', 'Y2'] ['B4', 'R4']
#              ['W4', 'O4']
#              ['G2', 'B1']
#              ['Y4', 'W3']
#              ['G4', 'W1']
#
#
# Geração 62000
# 62000 D R B' L F' B' D L' D R' D' R' L U' F D' L' D B' F L D' B D F  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['W3', 'O2']
#              ['Y1', 'O1']
# ['B1', 'B3'] ['R3', 'G4'] ['W2', 'Y4']
# ['O4', 'R2'] ['G3', 'Y3'] ['G1', 'B2']
#              ['W1', 'R1']
#              ['Y2', 'O3']
#              ['B4', 'W4']
#              ['R4', 'G2']
#
#
# Geração 63000
# 63000 D R B' L F' B' D L' U' D' F D' R' D' U B D' R D U' D' R' B' U B  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['R1', 'B4']
#              ['R4', 'B3']
# ['Y3', 'B1'] ['W3', 'R3'] ['Y1', 'Y2']
# ['O2', 'G3'] ['W1', 'O1'] ['W2', 'B2']
#              ['R2', 'G4']
#              ['G2', 'O3']
#              ['Y4', 'W4']
#              ['G1', 'O4']
#
#
# Geração 64000
# 64000 D R B' L F' B' D U' F' L' D' B U' L' R' D' R F D U B U U D D  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['O3', 'W3']
#              ['O4', 'W2']
# ['B2', 'B4'] ['Y2', 'O1'] ['G4', 'R4']
# ['O2', 'B3'] ['Y1', 'R2'] ['G3', 'G1']
#              ['R3', 'W1']
#              ['G2', 'Y3']
#              ['Y4', 'R1']
#              ['W4', 'B1']
#
#
# Geração 65000
# 65000 D R B' L B' F' D L U' L D' B U L' D B U' L B L U L' L' B' B'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['O2', 'O3']
#              ['O1', 'Y1']
# ['G2', 'G4'] ['W2', 'B3'] ['R3', 'W4']
# ['R2', 'R1'] ['Y3', 'B1'] ['R4', 'Y2']
#              ['G1', 'W3']
#              ['G3', 'O4']
#              ['W1', 'B4']
#              ['Y4', 'B2']
#
#
# Geração 66000
# 66000 D R B' L B' F' D D B R' U F' D' B B F B' D' D' B' F' U' F' F' R'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['O2', 'R2']
#              ['W4', 'Y3']
# ['G2', 'B2'] ['O3', 'R1'] ['G1', 'W1']
# ['B1', 'B4'] ['O4', 'Y1'] ['R3', 'G4']
#              ['Y2', 'B3']
#              ['R4', 'W2']
#              ['W3', 'O1']
#              ['Y4', 'G3']
#
#
# Geração 67000
# 67000 D R B' L B' F' D R D L' D' U' B U' F R' F' L' D B' U R' L U B'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['R2', 'W3']
#              ['R1', 'Y4']
# ['G3', 'G1'] ['Y3', 'G2'] ['O2', 'R4']
# ['W2', 'O3'] ['B2', 'B3'] ['Y1', 'O4']
#              ['W4', 'R3']
#              ['G4', 'B4']
#              ['O1', 'Y2']
#              ['W1', 'B1']
#
#
# Geração 68000
# 68000 D R B' L F' B' D F' F' R' L' U' R B' D' F L B' D R' L' D L F R  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y3', 'G3']
#              ['O2', 'B3']
# ['G1', 'Y4'] ['G2', 'R3'] ['Y1', 'R2']
# ['G4', 'B4'] ['O4', 'O3'] ['B2', 'W3']
#              ['Y2', 'W4']
#              ['O1', 'R4']
#              ['W2', 'B1']
#              ['R1', 'W1']
#
#
# Geração 69000
# 69000 D R B' L F' B' D B' U F' B R D B' F D D F' R D R D L B L'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['G2', 'G4']
#              ['W1', 'G1']
# ['Y4', 'G3'] ['R2', 'Y3'] ['R1', 'W2']
# ['W4', 'B4'] ['O4', 'R4'] ['W3', 'R3']
#              ['Y2', 'B1']
#              ['O3', 'Y1']
#              ['B2', 'B3']
#              ['O2', 'O1']
#
#
# Geração 70000
# 70000 D R B' L F' B' D U' D' R' D' F U' D L' D' F B' D' B' L' F U' R B  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['B3', 'Y3']
#              ['Y2', 'B2']
# ['Y1', 'O4'] ['B4', 'O3'] ['W4', 'R1']
# ['R4', 'G3'] ['W1', 'Y4'] ['O2', 'W2']
#              ['R2', 'G2']
#              ['W3', 'O1']
#              ['B1', 'G4']
#              ['R3', 'G1']
#
#
# Geração 71000
# 71000 D R B' L F' B' D D D U R' L U' L' B' F' D' F B' U U R' U D' L'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['O4', 'G1']
#              ['W2', 'W4']
# ['Y2', 'O1'] ['G4', 'B2'] ['O3', 'Y3']
# ['W3', 'G3'] ['W1', 'Y4'] ['O2', 'Y1']
#              ['R2', 'G2']
#              ['B1', 'B3']
#              ['R4', 'R3']
#              ['B4', 'R1']
#
#
# Geração 72000
# 72000 D R B' L B' F' D F L R U L R D' U R B' B' L U L' B R' B U  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['B4', 'W4']
#              ['R2', 'W3']
# ['O4', 'W1'] ['G3', 'R4'] ['B1', 'B2']
# ['G1', 'Y4'] ['O2', 'G4'] ['O1', 'R3']
#              ['G2', 'W2']
#              ['R1', 'Y1']
#              ['Y3', 'B3']
#              ['Y2', 'O3']
#
#
# Geração 73000
# 73000 D R B' L F' B' D R' F' U D' L L D' R D B' D B F' B R' B D' L'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['B3', 'O1']
#              ['O2', 'O4']
# ['Y1', 'Y4'] ['G2', 'B4'] ['Y2', 'G4']
# ['W1', 'R1'] ['Y3', 'W3'] ['B1', 'B2']
#              ['G1', 'R4']
#              ['R2', 'O3']
#              ['G3', 'W4']
#              ['R3', 'W2']
#
#
# Geração 74000
# 74000 D R B' L F' B' D L F' D B D L' B U' F D' L' U L R U' L' U F  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y3', 'R2']
#              ['B1', 'R3']
# ['G1', 'W3'] ['R4', 'Y1'] ['B3', 'W1']
# ['O3', 'W2'] ['G4', 'G2'] ['Y4', 'O4']
#              ['O1', 'O2']
#              ['B2', 'B4']
#              ['W4', 'Y2']
#              ['R1', 'G3']
#
#
# Geração 75000
# 75000 D R B' L F' B' D D B' U F L' F L R' B' B' D B L R' B' U B' R'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['O3', 'G2']
#              ['R4', 'R2']
# ['B2', 'B1'] ['W3', 'W1'] ['G3', 'O2']
# ['R1', 'B3'] ['Y1', 'O1'] ['W2', 'O4']
#              ['R3', 'G4']
#              ['Y3', 'B4']
#              ['G1', 'Y2']
#              ['W4', 'Y4']
#
#
# Geração 76000
# 76000 D R B' L B' F' D F' D' U L' D' F' D' B D' B R' U' B L' U R' D F'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['W2', 'G3']
#              ['R1', 'B4']
# ['G4', 'G1'] ['Y3', 'Y2'] ['O4', 'R2']
# ['Y1', 'Y4'] ['O2', 'B2'] ['W4', 'B1']
#              ['G2', 'O3']
#              ['R3', 'W3']
#              ['B3', 'R4']
#              ['O1', 'W1']
#
#
# Geração 77000
# 77000 D R B' L B' F' D R D' F' L F' R' F' R' D' F' D U L B F R' D' R  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['B1', 'O4']
#              ['G3', 'W4']
# ['R4', 'R2'] ['W1', 'B2'] ['O3', 'B4']
# ['O1', 'R3'] ['B3', 'R1'] ['Y3', 'O2']
#              ['Y1', 'G1']
#              ['W2', 'Y4']
#              ['G4', 'G2']
#              ['W3', 'Y2']
#
#
# Geração 78000
# 78000 D R B' L B' F' D F B L F B' F' L D' R' B R R L' R B' D F B'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y4', 'R4']
#              ['Y3', 'W2']
# ['O2', 'R1'] ['G1', 'O1'] ['G4', 'B1']
# ['R2', 'B3'] ['Y1', 'Y2'] ['B4', 'W4']
#              ['R3', 'O4']
#              ['G3', 'B2']
#              ['W1', 'O3']
#              ['G2', 'W3']
#
#
# Geração 79000
# 79000 D R B' L B' F' D U L B L' D' D' R F' L' B F' L' D' U' D R' D' R  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['B4', 'R4']
#              ['B3', 'W4']
# ['O4', 'R3'] ['Y1', 'B2'] ['O3', 'B1']
# ['W1', 'W2'] ['G4', 'G2'] ['Y4', 'G1']
#              ['O1', 'O2']
#              ['R2', 'Y3']
#              ['G3', 'R1']
#              ['Y2', 'W3']
#
#
# Geração 80000
# 80000 D R B' L B' F' D D R U' U' F' U D F' L' R' D' L D' R' R' D F' B  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['W1', 'Y1']
#              ['W2', 'O4']
# ['R2', 'O1'] ['G4', 'B4'] ['Y2', 'B3']
# ['G2', 'Y3'] ['G1', 'O3'] ['B2', 'W3']
#              ['R1', 'W4']
#              ['Y4', 'R4']
#              ['O2', 'B1']
#              ['G3', 'R3']
#
#
# Geração 81000
# 81000 D R B' L B' F' D L' B F' U F' U' F R D' U F D' R' F L' D' U B  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['O1', 'O3']
#              ['R2', 'B1']
# ['W2', 'W1'] ['G3', 'W3'] ['R4', 'W4']
# ['B4', 'O2'] ['G2', 'Y3'] ['G1', 'R3']
#              ['Y4', 'R1']
#              ['O4', 'Y1']
#              ['Y2', 'B3']
#              ['G4', 'B2']
#
#
# Geração 82000
# 82000 D R B' L F' B' D D R' L' U L' U' R B R' U D B' F B' L R' D F'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y2', 'Y4']
#              ['B1', 'R1']
# ['B4', 'W3'] ['R4', 'G1'] ['Y3', 'G2']
# ['B3', 'O1'] ['W2', 'R2'] ['G3', 'W4']
#              ['G4', 'W1']
#              ['Y1', 'B2']
#              ['R3', 'O3']
#              ['O4', 'O2']
#
#
# Geração 83000
# 83000 D R B' L F' B' D F' U' F' U' L' R' L D' B U R U R D L U L' B  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y4', 'Y2']
#              ['G1', 'R3']
# ['O2', 'Y3'] ['R1', 'Y1'] ['B3', 'O4']
# ['W1', 'W4'] ['O3', 'W2'] ['G4', 'W3']
#              ['B2', 'O1']
#              ['R2', 'R4']
#              ['G3', 'B1']
#              ['G2', 'B4']
#
#
# Geração 84000
# 84000 D R B' L F' B' D L B' D U R U B' U L' F' D' U' F B U F' F' L  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['G2', 'B2']
#              ['W3', 'R2']
# ['Y4', 'R4'] ['B1', 'W1'] ['G3', 'O3']
# ['R1', 'W2'] ['G4', 'R3'] ['B3', 'Y2']
#              ['O1', 'Y1']
#              ['Y3', 'O4']
#              ['G1', 'B4']
#              ['O2', 'W4']
#
#
# Geração 85000
# 85000 D R B' L F' B' D R U' L R D' L L F' L' U R D' R F U' B B F'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['G1', 'W2']
#              ['B1', 'O4']
# ['R1', 'W3'] ['R4', 'B4'] ['Y2', 'O1']
# ['O3', 'W1'] ['R2', 'O2'] ['G2', 'B3']
#              ['G3', 'Y4']
#              ['B2', 'R3']
#              ['W4', 'Y1']
#              ['Y3', 'G4']
#
#
# Geração 86000
# 86000 D R B' L F' B' D F L' R B' D' D' L F U' U' B' R L U F U D L'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['O1', 'R1']
#              ['O2', 'B3']
# ['W2', 'Y4'] ['G2', 'R3'] ['Y1', 'G1']
# ['B1', 'R2'] ['G3', 'W4'] ['O3', 'O4']
#              ['W1', 'B2']
#              ['R4', 'B4']
#              ['W3', 'Y2']
#              ['G4', 'Y3']
#
#
# Geração 87000
# 87000 D R B' L F' B' D D L' D F' D' U R U' B U L' R F D U' L D' D'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['W3', 'G3']
#              ['Y3', 'O2']
# ['B1', 'R1'] ['G1', 'Y4'] ['G2', 'R2']
# ['B3', 'O3'] ['B2', 'G4'] ['O1', 'B4']
#              ['W4', 'W2']
#              ['Y1', 'Y2']
#              ['R3', 'O4']
#              ['R4', 'W1']
#
#
# Geração 88000
# 88000 D R B' L B' F' D U R B' U R R L' F F F U' U' F' D' B B U' R  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['O4', 'O3']
#              ['W2', 'G1']
# ['Y2', 'O1'] ['G4', 'Y3'] ['R1', 'W4']
# ['Y4', 'B1'] ['R4', 'Y1'] ['R3', 'W1']
#              ['W3', 'B3']
#              ['O2', 'G3']
#              ['G2', 'R2']
#              ['B4', 'B2']
#
#
# Geração 89000
# 89000 D R B' L B' F' D F' R F' F' D D B D' B' R' F B L' L' B' U L F'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['R2', 'B3']
#              ['G1', 'O3']
# ['G3', 'Y3'] ['R1', 'W4'] ['B2', 'R3']
# ['R4', 'G2'] ['Y4', 'O4'] ['Y2', 'W2']
#              ['O2', 'B4']
#              ['W3', 'O1']
#              ['B1', 'G4']
#              ['W1', 'Y1']
#
#
# Geração 90000
# 90000 D R B' L B' F' D U' B F' B' F D' U' R' L D B U D' L B' L B D  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['B2', 'Y1']
#              ['Y4', 'R2']
# ['W4', 'G2'] ['O2', 'W1'] ['G3', 'B3']
# ['G1', 'B1'] ['R4', 'G4'] ['O1', 'O4']
#              ['W3', 'W2']
#              ['R1', 'B4']
#              ['Y3', 'Y2']
#              ['O3', 'R3']
#
#
# Geração 91000
# 91000 D R B' L F' B' D B' L R' U D D D D B' B' D' B' L' B' D' L D L'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y3', 'G3']
#              ['R3', 'Y4']
# ['G1', 'Y1'] ['B3', 'G2'] ['O2', 'R2']
# ['B4', 'R4'] ['W3', 'G4'] ['O1', 'O3']
#              ['B1', 'W2']
#              ['O4', 'W4']
#              ['Y2', 'B2']
#              ['R1', 'W1']
#
#
# Geração 92000
# 92000 D R B' L F' B' D D L' B' F' L' L' B L' R B' R' L F' D' U B B D  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['R3', 'R1']
#              ['O4', 'W3']
# ['B3', 'B4'] ['Y2', 'R4'] ['B1', 'G1']
# ['W4', 'Y4'] ['O2', 'R2'] ['G3', 'O1']
#              ['G2', 'W1']
#              ['O3', 'G4']
#              ['B2', 'W2']
#              ['Y1', 'Y3']
#
#
# Geração 93000
# 93000 D R B' L F' B' D D L' R' F D F U' L' U' B' D L' U L' B' U L' U  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['O3', 'B4']
#              ['O1', 'G2']
# ['B2', 'G4'] ['W2', 'O2'] ['Y4', 'Y2']
# ['R2', 'R3'] ['B3', 'B1'] ['R4', 'R1']
#              ['Y1', 'W3']
#              ['G3', 'G1']
#              ['W1', 'Y3']
#              ['W4', 'O4']
#
#
# Geração 94000
# 94000 D R B' L B' F' D D U' B D D U D' F' U' F' B' L L B D B' R U'  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['G2', 'Y2']
#              ['W4', 'R4']
# ['Y4', 'B2'] ['O3', 'B1'] ['W3', 'O4']
# ['R1', 'G3'] ['W1', 'Y1'] ['R3', 'W2']
#              ['R2', 'B3']
#              ['Y3', 'O1']
#              ['G1', 'G4']
#              ['O2', 'B4']
#
#
# Geração 95000
# 95000 D R B' L B' F' D U L U R R L' F R' L D' B' F L R D F' U' D  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['Y4', 'W2']
#              ['Y1', 'W4']
# ['O2', 'B3'] ['R3', 'B2'] ['O3', 'O1']
# ['W1', 'G1'] ['R1', 'B1'] ['R4', 'Y2']
#              ['Y3', 'W3']
#              ['R2', 'O4']
#              ['G3', 'B4']
#              ['G2', 'G4']
#
#
# Geração 96000
# 96000 D R B' L B' F' D D L U' L' B L B L F' U B' D B' F F R B' L  - Fitness = 6.875, movesUntilSolved = 24, lastImprovementPoint = 7
#
#              ['R1', 'Y2']
#              ['W2', 'B1']
# ['Y3', 'O1'] ['G4', 'W3'] ['R4', 'O4']
# ['G2', 'B2'] ['W4', 'R2'] ['G3', 'Y1']
#              ['O3', 'W1']
#              ['Y4', 'B3']
#              ['O2', 'R3']
#              ['G1', 'B4']
#
#
# Genetic Algorithm completed
#
# Applying solution
# D R B' L B' F' D L' F L D L R F U L' R' F L D R' U' L' R' U'  - Fitness = 0.9523809523809523, movesUntilSolved = 19, lastImprovementPoint = 20
# Sequence to apply: ['D', 'R', "B'", 'L', "B'", "F'", 'D', "L'", 'F', 'L', 'D', 'L', 'R', 'F', 'U', "L'", "R'", 'F', 'L', 'D']
# Before applying:
#
#              ['B3', 'O2']
#              ['O4', 'R4']
# ['Y1', 'B4'] ['Y2', 'B1'] ['W3', 'Y4']
# ['G3', 'G1'] ['R1', 'G4'] ['O1', 'W4']
#              ['Y3', 'W2']
#              ['W1', 'B2']
#              ['R2', 'O3']
#              ['R3', 'G2']
#
# After applying
#
#              ['G1', 'G2']
#              ['G3', 'G4']
# ['R1', 'R2'] ['W1', 'W2'] ['O1', 'O2']
# ['R3', 'R4'] ['W3', 'W4'] ['O3', 'O4']
#              ['B1', 'B2']
#              ['B3', 'B4']
#              ['Y1', 'Y2']
#              ['Y3', 'Y4']
